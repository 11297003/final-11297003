# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import yfinance as yf
import pandas as pd

# %%
tickers_list=['2303.tw','2317.tw','2330.tw']

# %%
data=pd.DataFrame(columns=tickers_list)

# %%
for ticker in tickers_list:
    data[ticker] = yf.download(ticker, period='10y',interval='1d')['Adj Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
data.head()
# Out:
#              2303.tw    2317.tw    2330.tw
# Date
# 2014-04-23  8.407660  57.710838  89.566360
# 2014-04-24  8.375813  57.710838  89.566360
# 2014-04-25  8.152884  56.668655  87.715820
# 2014-04-28  8.152884  56.277836  88.085930
# 2014-04-29  8.312119  57.189743  89.196251

# %%
data.plot(figsize=(10,7))
plt.legend()
plt.title("Adjusted Close Price", fontsize=16)
plt.ylabel('Price',fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(which="major", color='k', linestyle='-',linewidth=0.5)
plt.show()
